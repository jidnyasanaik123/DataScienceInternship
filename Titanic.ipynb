# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
xtrain=df_train.drop(['PassengerId','Age', 'Survived', 'Name', 'Sex',  'Ticket',  'Cabin', 'Embarked'],axis=1)
ytrain=df_train['Survived']

# %%
xtrain.head()
# Out:
#    Pclass  SibSp  Parch     Fare
# 0       3      1      0   7.2500
# 1       1      1      0  71.2833
# 2       3      0      0   7.9250
# 3       1      1      0  53.1000
# 4       3      0      0   8.0500

# %%
xtrain.tail()
# Out:
#      Pclass  SibSp  Parch   Fare
# 886       2      0      0  13.00
# 887       1      0      0  30.00
# 888       3      1      2  23.45
# 889       1      0      0  30.00
# 890       3      0      0   7.75

# %%
xtrain.isnull().sum()
# Out:
# Pclass    0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
ytrain.isnull().sum()
# Out:
# 0

# %%
xtrain.dtypes
# Out:
# Pclass      int64
# SibSp       int64
# Parch       int64
# Fare      float64
# dtype: object

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2,k="all")
fit = bestfeatures.fit(xtrain,ytrain)
#print(fit.scores_)
dfscores =pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(xtrain.columns)
featuresScores = pd.concat([dfcolumns, dfscores],axis=1)
featuresScores.columns=['Specs','Score']
print(featuresScores)
# Out:
#     Specs        Score
# 0  Pclass    30.873699
# 1   SibSp     2.581865
# 2   Parch    10.097499
# 3    Fare  4518.319091

# %%
xtest=df_test.drop(['PassengerId', 'Age', 'Name', 'Sex',  'Ticket',  'Cabin', 'Embarked'],axis=1)

# %%
xtest.shape
# Out:
# (418, 4)

# %%
xtest.head()
# Out:
#    Pclass  SibSp  Parch     Fare
# 0       3      0      0   7.8292
# 1       3      1      0   7.0000
# 2       2      0      0   9.6875
# 3       3      0      0   8.6625
# 4       3      1      1  12.2875

# %%
xtest.tail()
# Out:
#      Pclass  SibSp  Parch      Fare
# 413       3      0      0    8.0500
# 414       1      0      0  108.9000
# 415       3      0      0    7.2500
# 416       3      0      0    8.0500
# 417       3      1      1   22.3583

# %%
xtest.head(60)
# Out:
#     Pclass  SibSp  Parch      Fare
# 0        3      0      0    7.8292
# 1        3      1      0    7.0000
# 2        2      0      0    9.6875
# 3        3      0      0    8.6625
# 4        3      1      1   12.2875
# 5        3      0      0    9.2250
# 6        3      0      0    7.6292
# 7        2      1      1   29.0000
# 8        3      0      0    7.2292
# 9        3      2      0   24.1500
# 10       3      0      0    7.8958
# 11       1      0      0   26.0000
# 12       1      1      0   82.2667
# 13       2      1      0   26.0000
# 14       1      1      0   61.1750
# 15       2      1      0   27.7208
# 16       2      0      0   12.3500
# 17       3      0      0    7.2250
# 18       3      1      0    7.9250
# 19       3      0      0    7.2250
# 20       1      1      0   59.4000
# 21       3      0      1    3.1708
# 22       1      0      0   31.6833
# 23       1      0      1   61.3792
# 24       1      1      3  262.3750
# 25       3      1      0   14.5000
# ...

# %%
xtest.isnull().sum()
# Out:
# Pclass    0
# SibSp     0
# Parch     0
# Fare      1
# dtype: int64

# %%
#xtest['Fare'].dropna(axis=0,inplace=True)

# %%
xtest.isnull().sum()
# Out:
# Pclass    0
# SibSp     0
# Parch     0
# Fare      1
# dtype: int64

# %%
xtest['Fare'].tail()
# Out:
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, dtype: float64

# %%
xtest['Fare']
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
xtest['Fare']=xtest['Fare'].replace(np.nan,0)

# %%
from sklearn.linear_model import LogisticRegression
LOR= LogisticRegression(random_state=0)

LOR.fit(xtrain,ytrain)

acc=LOR.predict(xtest)
submission = pd.DataFrame({'PassengerId': df_test.PassengerId, 'Survived': acc})
submission.to_csv('submission.csv',index=False)

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
userinp=np.array([[2,0,1,150]])
Prediction=LOR.predict(userinp)
# Out:
# c:\Users\manas\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print('The Passenger Survived(1) or Not Survived(0):',Prediction)
# Out:
# The Passenger Survived(1) or Not Survived(0): [1]
